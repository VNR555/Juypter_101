# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Vinod R\Desktop\Tex\List.csv")
df
# Out:
#     Rank                      Name                    Industry
# 0      1                   Walmart                      Retail
# 1      2                    Amazon  Retail and cloud computing
# 2      3                ExxonMobil          Petroleum industry
# 3      4                     Apple        Electronics industry
# 4      5        UnitedHealth Group                  Healthcare
# ..   ...                       ...                         ...
# 95    96                  Best Buy                      Retail
# 96    97      Bristol-Myers Squibb     Pharmaceutical industry
# 97    98           United Airlines                     Airline
# 98    99  Thermo Fisher Scientific      Laboratory instruments
# 99   100                  Qualcomm                  Technology
#
# [100 rows x 3 columns]

# %%
# If it's a text file with a specific delimiter (e.g., tab-separated values)
# df = pd.read_csv(r"C:\Users\Vinod R\Desktop\Tex\News Portals.txt", delimiter='\t')
# print(df)

# %%
#if you want to import a text file:

#df = pd.read_csv(r"(the file path)", sep = '\t')
#df

#'\t' - The sep parameter specifies the delimiter that separates the values in the file. \t represents a tab character.
#This means the file is expected to be a tab-separated values (TSV) file, where each column of data is separated by a tab.

#we can also use:
#df = pd.read_table(r"(the file path)")
#df

#or
#df = pd.read_table(r"(the file path.csv)", sep = ',')
#df

# %%
df = pd.read_csv(r"C:\Users\Vinod R\Desktop\Tex\News Portals.txt")
df
# Out:
#                                             Flipboard
# 0                                         Google News
# 1               Feedly (subcription based RSS reader)
# 2                     The New York Times (newsletter)
# 3                    The Washington Post (newsletter)
# 4                                    BBC (newsletter)
# 5                           The Guardian (newsletter)
# 6                             Morning Brew (business)
# 7                            The Skimm (general news)
# 8                           Axios (politics and tech)
# 9           The Daily by The New York Times (podcast)
# 10                          Up First by NPR (podcast)
# 11                            BBC Global News Podcast
# 12                             Inoreader (RSS reader)
# 13                                                CNN
# 14                                                BBC
# 15                                            Reuters
# ...

# %%
df = pd.read_excel (r"C:\Users\Vinod R\Desktop\Tex\Data.xlsx", sheet_name = 'Industry')
df
# Out:
#     Rank                                 Name  \
# 0     50                                Tesla
# 1     51                     Procter & Gamble
# 2     52         United States Postal Service
# 3     53                           Albertsons
# 4     54                     General Electric
# 5     55                              MetLife
# 6     56                        Goldman Sachs
# 7     57                                Sysco
# 8     58                        Bunge Limited
# 9     59                      RTX Corporation
# 10    60                               Boeing
# 11    61                         StoneX Group
# 12    62                      Lockheed Martin
# 13    63                       Morgan Stanley
# 14    64                                Intel
# 15    65                                   HP
# 16    66                            TD Synnex
# 17    67                                  IBM
# 18    68                       HCA Healthcare
# ...

# %%
df2 = pd.read_excel (r"C:\Users\Vinod R\Desktop\Tex\Data.xlsx")
df2
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                           ExxonMobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                              Cencora
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
#for displaying all the rows in the file

# %%
pd.set_option('display.max.rows', 101)
#after typing this code, run the df once again

#we can do this on columns as well:
#pd.set_option('display.max.column', 234)

# %%
#this will shows the summary info

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rank      100 non-null    int64
#  1   Name      100 non-null    object
#  2   Industry  100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rank      100 non-null    int64
#  1   Name      100 non-null    object
#  2   Industry  100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB

# %%
#for getting the total number of rows and colums alone

# %%
df2.shape
# Out:
# (100, 3)

# %%
#this will give the first five values in the table

# %%
df.head()
# Out:
#    Rank                Name                    Industry
# 0     1             Walmart                      Retail
# 1     2              Amazon  Retail and cloud computing
# 2     3          ExxonMobil          Petroleum industry
# 3     4               Apple        Electronics industry
# 4     5  UnitedHealth Group                  Healthcare

# %%
#we need to specify the number of rows we need if more data need to be fetched

# %%
df.head(10)
# Out:
#    Rank                  Name                        Industry
# 0     1               Walmart                          Retail
# 1     2                Amazon      Retail and cloud computing
# 2     3            ExxonMobil              Petroleum industry
# 3     4                 Apple            Electronics industry
# 4     5    UnitedHealth Group                      Healthcare
# 5     6            CVS Health                      Healthcare
# 6     7    Berkshire Hathaway                    Conglomerate
# 7     8              Alphabet  Technology and cloud computing
# 8     9  McKesson Corporation                          Health
# 9    10   Chevron Corporation              Petroleum industry

# %%
# this will give us the last 10 rows within our dataset

# %%
df.tail(10)
# Out:
#     Rank                      Name                 Industry
# 90    91         American Airlines                  Airline
# 91    92                       CHS  Agriculture cooperative
# 92    93    Performance Food Group          Food processing
# 93    94                PBF Energy       Petroleum industry
# 94    95                      Nike                  Apparel
# 95    96                  Best Buy                   Retail
# 96    97      Bristol-Myers Squibb  Pharmaceutical industry
# 97    98           United Airlines                  Airline
# 98    99  Thermo Fisher Scientific   Laboratory instruments
# 99   100                  Qualcomm               Technology

# %%
#for getting specific column data

# %%
df2['Name']
# Out:
# 0                                 Walmart
# 1                                  Amazon
# 2                              ExxonMobil
# 3                                   Apple
# 4                      UnitedHealth Group
# 5                              CVS Health
# 6                      Berkshire Hathaway
# 7                                Alphabet
# 8                    McKesson Corporation
# 9                     Chevron Corporation
# 10                                Cencora
# 11                                 Costco
# 12                              Microsoft
# 13                        Cardinal Health
# 14                                  Cigna
# 15                     Marathon Petroleum
# 16                            Phillips 66
# 17                          Valero Energy
# 18                     Ford Motor Company
# 19                         The Home Depot
# 20                         General Motors
# 21                        Elevance Health
# ...

# %%
df2.loc[55]
# Out:
# Rank                   56
# Name        Goldman Sachs
# Industry       Financials
# Name: 55, dtype: object

# %%
df2.iloc[55]
# Out:
# Rank                   56
# Name        Goldman Sachs
# Industry       Financials
# Name: 55, dtype: object
